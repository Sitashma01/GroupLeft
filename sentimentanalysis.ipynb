# %%
# !pip install transformers

# %%
from transformers import pipeline

# Load sentiment analysis pipeline
classifier = pipeline("sentiment-analysis")

# Analyze text
result = classifier("I love learning Artificial Intelligence!")

print(result)
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.9996731281280518}]

# %%
from transformers import pipeline

# Load sentiment analysis pipeline
classifier = pipeline("sentiment-analysis", top_k=2)

sentence = input("Enter a sentence: ")

# Analyze text
results = classifier(sentence)[0]

print(results)

print("\n-- both scores---")
for item in results:
  label = item['label']
  score = round(item['score'], 4)
  print(f"{label}: {score}")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# Enter a sentence: i love you gandu
# [{'label': 'POSITIVE', 'score': 0.9998570680618286}, {'label': 'NEGATIVE', 'score': 0.00014290580293163657}]
#
# -- both scores---
# POSITIVE: 0.9999
# NEGATIVE: 0.0001

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer

model_name = "t5-small"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

text = "summerize: " + """Kathmandu is the capital city of Nepal and the largest urban center in the country.
It is located in the Kathmandu Valley, surrounded by beautiful hills and mountains. The city is famous for its
rich history, ancient temples, and vibrant cultural heritage. Important landmarks such as Swayambhunath and
 Pashupatinath Temple attract visitors from around the world. Kathmandu serves as the political, economic, and
 educational hub of Nepal. Its unique blend of tradition and modern development makes it one of the most fascinating
 cities in South Asia."""
# Out:
# Loading weights:   0%|          | 0/131 [00:00<?, ?it/s]
