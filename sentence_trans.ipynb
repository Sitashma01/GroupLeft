# %%
# !pip install sentence_transformers

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
embedding = model.encode("I love AI and love working with it.")
print(embedding.shape)
# Out:
# (384,)

# %%
# !pip install sentence_transformers

# %%
from sentence_transformers import sentence_transformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
s1 = model.encode("I Love AI")
s2 = model.encode("AI is Amazing to work with")

# %%
similarity = cosine_similarity([s1],[s2])

# %%
print(similarity)
# Out:
# [[0.8122884]]
